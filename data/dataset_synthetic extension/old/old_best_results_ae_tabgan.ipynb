# %%
import pandas as pd

# Load datasets
ae_df = pd.read_csv("hyperparameter_results/ae_gridsearch_results.csv")
tabgan_df = pd.read_csv("hyperparameter_results/tabgan_gridsearch_run_results.csv")

# Best 4 AE results: smallest best_val_loss
best_ae = ae_df.sort_values("best_val_loss", ascending=True).head(4)

# Best 4 TabGAN results: largest mean_total_score
best_tabgan = tabgan_df.sort_values("mean_total_score", ascending=False).head(4)

print("Best 4 AE results")
display(best_ae)

print("\nBest 4 TabGAN results")
display(best_tabgan)
# Out:
# Best 4 AE results
#                                       run_name  best_epoch  best_val_loss  \
# 0    ae_ld8_hd256-128_bs64_lr5e-05_do0.0_wd0.0          49       0.000010
# 1     ae_ld8_hd64-32_bs128_lr0.001_do0.0_wd0.0          47       0.000011
# 2  ae_ld8_hd256-128_bs64_lr5e-05_do0.0_wd1e-05          38       0.000011
# 3  ae_ld8_hd256-128_bs128_lr0.0001_do0.0_wd0.0          45       0.000013
#
#    test_loss  input_dim  latent_dim hidden_dims  dropout  batch_size  \
# 0   0.000011          6           8  (256, 128)      0.0          64
# 1   0.000012          6           8    (64, 32)      0.0         128
# 2   0.000012          6           8  (256, 128)      0.0          64
# 3   0.000014          6           8  (256, 128)      0.0         128
#
#    learning_rate  weight_decay
# 0        0.00005       0.00000
# 1        0.00100       0.00000
# 2        0.00005       0.00001
# 3        0.00010       0.00000
# Best 4 TabGAN results
# ...

# %%
s
